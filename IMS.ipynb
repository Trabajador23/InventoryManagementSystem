# %%
def main():
    Records={
              '1001':{"ProductName":"Maida","BrandName":"Aashirwaad","Quantity":50,"NetWeight(kg)":1,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'2/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1002':{"ProductName":"Atta" ,"BrandName":"Aashirwaad","Quantity":50,"NetWeight(kg)":1,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'2/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1003':{"ProductName":"Pepper","BrandName":"Sambangi","Quantity":55,"NetWeight(kg)":0.05,"MRP":30,"DiscountedPrice":29,"PackagedDate":'8/21',"ExpiryDate":'1/2023',"Lable":"Green(veg)","Type":"Groceries"},
              '1004':{"ProductName":"TeaPowder","BrandName":"3Roses","Quantity":35,"NetWeight(kg)":0.5,"MRP":250,"DiscountedPrice":240,"PackagedDate":'6/21',"ExpiryDate":'12/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1005':{"ProductName":"BasmatiRice","BrandName":"IndiaGate","Quantity":20,"NetWeight(kg)":1,"MRP":100,"DiscountedPrice":95,"PackagedDate":'8/21',"ExpiryDate":'2/2023',"Lable":"Green(veg)","Type":"Groceries"},
              '1006':{"ProductName":"TomatoChauce","BrandName":"Maagi","Quantity":25,"NetWeight(kg)":0.25,"MRP":35,"DiscountedPrice":34,"PackagedDate":'7/21',"ExpiryDate":'12/2021',"Lable":"Green(veg)","Type":"Groceries"},
              '1007':{"ProductName":"InstantNooodles","BrandName":"Yippee","Quantity":50,"NetWeight(kg)":0.15,"MRP":12,"DiscountedPrice":10,"PackagedDate":'8/21',"ExpiryDate":'2/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1008':{"ProductName":"CoffeePowder","BrandName":"Bru","Quantity":25,"NetWeight(kg)":0.25,"MRP":150,"DiscountedPrice":140,"PackagedDate":'7/21',"ExpiryDate":'1/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1009':{"ProductName":"ChilliPowder","BrandName":"Aachi","Quantity":75,"NetWeight(kg)":0.1,"MRP":15,"DiscountedPrice":13,"PackagedDate":'7/21',"ExpiryDate":'4/2023',"Lable":"Green(veg)","Type":"Groceries"},
              '1010':{"ProductName":"UradDal","BrandName":"Udhayam","Quantity":40,"NetWeight(kg)":1,"MRP":200,"DiscountedPrice":190,"PackagedDate":'7/21',"ExpiryDate":'6/2023',"Lable":"Green(veg)","Type":"Groceries"},
              '1011':{"ProductName":"PackagedChicken","BrandName":"Deliciuos","Quantity":12,"NetWeight(kg)":1,"MRP":220,"DiscountedPrice":200,"PackagedDate":'7/21',"ExpiryDate":'9/2021',"Lable":"Red(nonveg)","Type":"Groceries"},
              '1012':{"ProductName":"PackagedFishMeat","BrandName":"Delicious","Quantity":20,"NetWeight(kg)":1,"MRP":180,"DiscountedPrice":175,"PackagedDate":'7/21',"ExpiryDate":'9/2021',"Lable":"Red(nonveg)","Type":"Groceries"},
              '1013':{"ProductName":"sugar","BrandName":"Tata","Quantity":60,"NetWeight(kg)":1,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'9/2022',"Lable":"Green(veg)","Type":"Groceries"},
              '1014':{"ProductName":"Salt","BrandName":"Tata","Quantity":40,"NetWeight(kg)":1,"MRP":20,"DiscountedPrice":19,"PackagedDate":'7/21',"ExpiryDate":'5/2024',"Lable":"Green(veg)","Type":"Groceries"},
              '1015':{"ProductName":"Raagi","BrandName":"Goodie","Quantity":30,"NetWeight(kg)":1,"MRP":70,"DiscountedPrice":67,"PackagedDate":'7/21',"ExpiryDate":'9/2022',"Lable":"Green(veg)","Type":"Groceries"},                
              '1016':{"ProductName":"DetergentPowder","BrandName":"Rin","Quantity":45,"NetWeight(kg)":1,"MRP":300,"DiscountedPrice":280,"PackagedDate":'7/21',"ExpiryDate":'2/2024',"Type":"HomeEssentials"},
              '1017':{"ProductName":"DetergentSoap" ,"BrandName":"Rin","Quantity":75,"NetWeight(kg)":.25,"MRP":15,"DiscountedPrice":12,"PackagedDate":'6/21',"ExpiryDate":'2/2022',"Type":"HomeEssentials"},
              '1018':{"ProductName":"FaceWash","BrandName":"Garnier","Quantity":25,"NetWeight(kg)":0.2,"MRP":50,"DiscountedPrice":48,"PackagedDate":'8/21',"ExpiryDate":'1/2022',"Type":"HomeEssentials"},
              '1019':{"ProductName":"BathingSoap","BrandName":"Dove","Quantity":30,"NetWeight(kg)":0.18,"MRP":60,"DiscountedPrice":55,"PackagedDate":'6/21',"ExpiryDate":'12/2022',"Type":"HomeEssentials"},
              '1020':{"ProductName":"DishwashSoap","BrandName":"vim","Quantity":20,"NetWeight(kg)":0.2,"MRP":20,"DiscountedPrice":18,"PackagedDate":'8/21',"ExpiryDate":'2/2023',"Type":"HomeEssentials"},
              '1021':{"ProductName":"Toothbrush","BrandName":"Colgate","Quantity":100,"NetWeight(kg)":0.2,"MRP":25,"DiscountedPrice":24,"PackagedDate":'7/21',"ExpiryDate":'12/2023',"Type":"HomeEssentials"},
              '1022':{"ProductName":"ToothPaste","BrandName":"Colgate","Quantity":50,"NetWeight(kg)":0.35,"MRP":60,"DiscountedPrice":57,"PackagedDate":'8/21',"ExpiryDate":'2/2022',"Type":"HomeEssentials"},
              '1023':{"ProductName":"FloorCleaner","BrandName":"Lyzal","Quantity":40,"NetWeight(kg)":1,"MRP":250,"DiscountedPrice":240,"PackagedDate":'7/21',"ExpiryDate":'1/2023',"Type":"HomeEssentials"},
              '1024':{"ProductName":"Sanitizer","BrandName":"Lifeboy","Quantity":30,"NetWeight(kg)":.2,"MRP":45,"DiscountedPrice":44,"PackagedDate":'6/21',"ExpiryDate":'4/2023',"Type":"HomeEssentials"},
              '1025':{"ProductName":"Shampoo","BrandName":"Head&Shoulder","Quantity":25,"NetWeight(kg)":0.5,"MRP":200,"DiscountedPrice":195,"PackagedDate":'7/21',"ExpiryDate":'6/2022',"Type":"HomeEssentials"},
              '1026':{"ProductName":"FacePower","BrandName":"Ponds","Quantity":30,"NetWeight(kg)":0.5,"MRP":100,"DiscountedPrice":96,"PackagedDate":'6/21',"ExpiryDate":'9/2022',"Type":"HomeEssentials"},
              '1027':{"ProductName":"Shavinggel","BrandName":"Garnier","Quantity":20,"NetWeight(kg)":0.2,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'9/2023',"Type":"HomeEssentials"},
              '1028':{"ProductName":"ToiletCleaner","BrandName":"Harpic","Quantity":14,"NetWeight(kg)":0.5,"MRP":150,"DiscountedPrice":145,"PackagedDate":'7/21',"ExpiryDate":'9/2022',"Type":"HomeEssentials"},
              '1029':{"ProductName":"RoomSpray","BrandName":"Fragment","Quantity":15,"NetWeight(kg)":0.5,"MRP":200,"DiscountedPrice":190,"PackagedDate":'5/21',"ExpiryDate":'5/2022',"Type":"HomeEssentials"},
              '1030':{"ProductName":"BodySpray","BrandName":"Fogg","Quantity":30,"NetWeight(kg)":0.25,"MRP":90,"DiscountedPrice":86,"PackagedDate":'7/21',"ExpiryDate":'9/2022',"Type":"HomeEssentials"},
              '1031':{"ProductName":"Biscuit","BrandName":"MarieGold","Quantity":50,"NetWeight(kg)":0.35,"MRP":35,"DiscountedPrice":33,"PackagedDate":'7/21',"ExpiryDate":'2/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1032':{"ProductName":"cake" ,"BrandName":"Lava","Quantity":10,"NetWeight(kg)":1,"MRP":500,"DiscountedPrice":450,"PackagedDate":'7/21',"ExpiryDate":'9/2021',"Lable":"Red(Egg)","Type":"SnaksItem"},
              '1033':{"ProductName":"Mixture","BrandName":"Hotchips","Quantity":20,"NetWeight(kg)":0.05,"MRP":75,"DiscountedPrice":70,"PackagedDate":'8/21',"ExpiryDate":'12/2021',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1034':{"ProductName":"PotatoChips","BrandName":"Lays","Quantity":35,"NetWeight(kg)":0.1,"MRP":10,"DiscountedPrice":9,"PackagedDate":'6/21',"ExpiryDate":'12/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1035':{"ProductName":"MilkShake","BrandName":"Amul","Quantity":20,"NetWeight(kg)":0.25,"MRP":40,"DiscountedPrice":39,"PackagedDate":'8/21',"ExpiryDate":'1/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1036':{"ProductName":"Chocolate","BrandName":"DiaryMilk","Quantity":25,"NetWeight(kg)":0.125,"MRP":35,"DiscountedPrice":34,"PackagedDate":'7/21',"ExpiryDate":'12/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1037':{"ProductName":"Chocolate","BrandName":"5Star","Quantity":30,"NetWeight(kg)":0.15,"MRP":10,"DiscountedPrice":9,"PackagedDate":'8/21',"ExpiryDate":'2/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1038':{"ProductName":"chips","BrandName":"Kurkure","Quantity":25,"NetWeight(kg)":0.25,"MRP":10,"DiscountedPrice":9,"PackagedDate":'7/21',"ExpiryDate":'1/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1039':{"ProductName":"FingerChips","BrandName":"KFC","Quantity":20,"NetWeight(kg)":0.25,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'12/2021',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1040':{"ProductName":"Icecream","BrandName":"Chocobar","Quantity":20,"NetWeight(kg)":0.2,"MRP":30,"DiscountedPrice":28,"PackagedDate":'7/21',"ExpiryDate":'6/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1041':{"ProductName":"FamilyIcecream","BrandName":"Amul","Quantity":12,"NetWeight(kg)":1,"MRP":220,"DiscountedPrice":215,"PackagedDate":'7/21',"ExpiryDate":'9/2021',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1042':{"ProductName":"Rusk","BrandName":"Britania","Quantity":20,"NetWeight(kg)":0.4,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'9/2022',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1043':{"ProductName":"vegPuff","BrandName":"Delicious","Quantity":60,"NetWeight(kg)":0.3,"MRP":30,"DiscountedPrice":29,"PackagedDate":'7/21',"ExpiryDate":'8/2021',"Lable":"Green(veg)","Type":"SnaksItem"},
              '1044':{"ProductName":"ChikenPuffs","BrandName":"Delicious","Quantity":40,"NetWeight(kg)":0.4,"MRP":40,"DiscountedPrice":39,"PackagedDate":'7/21',"ExpiryDate":'8/2021',"Lable":"Red(nonveg)","Type":"SnaksItem"},
              '1045':{"ProductName":"ChikenRoll","BrandName":"Delicious","Quantity":30,"NetWeight(kg)":0.3,"MRP":50,"DiscountedPrice":48,"PackagedDate":'7/21',"ExpiryDate":'7/2021',"Lable":"Red(nonveg)","Type":"SnaksItem"}
              }

    sales={}
    Products={}
    import json
    inventory=json.dumps(Records)
    saving=open('Inventory.json','w')
    saving.write(inventory)
    saving.close()
    Products=json.loads(inventory)
    print("for purchasing - press 1")
    print('for adding product to inventory - press 2')
    x=input('Enter your choice: ')
    if x=='1':
      display_customer()
    elif x=='2':
      print('Press 1 - To increase quantity')
      print('press 2 - for adding new products ')
      y=input('enter your choice: ')
      if y=='1':
        addingquantity()
      elif y=='2':
        addingnewproducts()
      else:
        print('Invalid choice')
    else:
      print('Invalid choice')



def display_customer():
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('For Groceries- Press 1')
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('For Home Essentials- Press 2')
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('For Snaks Items- Press 3')
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('Already buyed evrything you wanted- Press 4 to exit')
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  preference=int(input('Select your Preference 1/2/3/4: '))
  if preference==1:
    items=Products.items()
    Groceries=list(items)[:15]
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    for key,value in Groceries:
      print(key,': ',value)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    purchase()
  elif preference==2:
    items=Products.items()
    HomeEssentials=list(items)[15:30]
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    for key,value in HomeEssentials:
      print(key,': ',value)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    purchase()
  elif preference==3:
    items=Products.items()
    SnaksItems=list(items)[30:45]
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    for key,value in SnaksItems:
      print(key,': ',value)
    print('------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    purchase()
  elif(preference==4):
    print('Thank you! Come again later')
  else:
    print('Please Enter a valid Option')
    purchase()

def purchase():
  Totalcost=0
  Totalsavings=0
  lstofItems=[]
  while(True):
    
   id=input('Enter the product ID: ')
   if id in Products.keys():
    quantity=int(input('Enter the quantity: '))
    if quantity<=Products[id]['Quantity']:
     Records[id]['Quantity']-=quantity
     lstofItems.append(id)
     lstofItems.append(quantity)
     Totalcost=Totalcost+quantity*Products[id]['DiscountedPrice']
     Totalsavings=Totalsavings+(Products[id]["MRP"]-Products[id]['DiscountedPrice'])*quantity
    else:
      print("sorry, We have only ",Products[id]['Quantity'],' units')
    option=input('Do you wish to buy more products in this Category(y/n)?:  ')

    if (option=='y' or option=='Y'):
      continue
    else:
      break
   else:
     print("Product not found, Please check the product ID")
  import time
  TimeofPurchase=time.ctime()
  print('Billing for ',Products[lstofItems[0]]['Type'])
  for  i in range(0,len(lstofItems),2):
    print('-------------------------------------------------------------------------------------------------------------------------------------------')
    print('ID: ',lstofItems[i],'  Quantity: ',lstofItems[i+1],'  MRP: ',Products[lstofItems[i]]["MRP"],'  OfferPrice: ',Products[lstofItems[i]]['DiscountedPrice'],' total cost: ',Products[lstofItems[i]]['DiscountedPrice']*lstofItems[i+1],'  Savings: ',(Products[lstofItems[i]]["MRP"]*lstofItems[i+1])-(Products[lstofItems[i]]['DiscountedPrice']*lstofItems[i+1]))
    
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('Total Cost of your purchase: ',Totalcost)
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print("Total Savings of your Purchase: ",Totalsavings)
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  print('Time of your Purchase: ',TimeofPurchase)
  print('---------------------------------------------------------------------------------------------------------------------------------------------')
  TransactionID=TimeofPurchase.replace(' ','')
  sales[TransactionID]={'Totalcost':Totalcost,'TimeofPurchase':TimeofPurchase}
  updatingjson()
  updatingTransaction()

def updatingjson():
 import json
 inventory=json.dumps(Records)
 saving=open('Inventory.json','w')
 saving.write(inventory)
 saving.close()
 Products=json.loads(inventory)
 print('Json File successfully Updated')

def updatingTransaction():
  import json
  transaction=json.dumps(sales)
  fd=open('Transcaction.json','w')
  fd.write(transaction)

def addingquantity():
  id=input('enter product id: ')
  if id in Products.keys():
    quantity=int(input('enter quantity: '))
    Products[id]['Quantity']+=quantity
    print('Quabtity successfully updated')
    updatingjson()
  else:
    print('Entered id is invalid')

def addingnewproducts():

  id=input('enter product id: ')
  if id not in Products.keys():
    ProductName=input('enter product name:')
    BrandName=input('enter a brandname')
    Quantity=int(input('enter quantity: '))
    MRP=int(input('enter a MRP: '))
    DiscountedPrice=int(input('enter selling price: '))
    weight=int(input('enter weigth : '))
    Products[id]={'ProductName':ProductName,'Brandname':BrandName,'Quantity':Quantity,'MRP':MRP,'DiscountedPrice':DiscountedPrice,'NetWeight(kg)':weight}
    print('New product added successfully')
    updatingjson()
main()
